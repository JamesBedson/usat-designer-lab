# %%
import SpeakerLayout as sl
import PlotUtils as pu

# %%
speaker_layout = sl.SpeakerLayout(num_speakers=9,
                                  radius=1,
                                  symmetry=True,
                                  hemisphere=True,
                                  random_seed=1234)

sph     = speaker_layout.generate_random_layout()
sph_deg = speaker_layout.spherical_to_degrees(sph)

pu.plot_speaker_layout_cartopy(sph_deg)
# Out:
# [[  34.47350107   51.25836047    1.        ]
#  [ 111.97957879   15.81860039    1.        ]
#  [  78.79099302   16.04929323    1.        ]
#  [ 141.36454507   53.30925588    1.        ]
#  [ -34.47350107   51.25836047    1.        ]
#  [-111.97957879   15.81860039    1.        ]
#  [ -78.79099302   16.04929323    1.        ]
#  [-141.36454507   53.30925588    1.        ]
#  [   0.            0.            1.        ]]
